# %% [markdown]
# ### Search and Destroy:
#
# This notebook defines the problem environment and analyses the agent's search of the target using the approaches of Rule 1 and Rule 2.

# %% [markdown]
# ## Environment

# %%
# Import libraries
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import math
import time
import pprint as pp
import pandas as pd
from operator import itemgetter
from matplotlib.colors import ListedColormap
from matplotlib.patches import Rectangle
import pdb

# %%
def place_target(env_terrains):
  a = env_terrains.shape[0] - 1

  i = random.randint(0,a)
  j = random.randint(0,a)

  return((i, j))

# %%
def generate_environment(a):

  # Generates an environment of dimension a*a

  env_terrains = np.zeros((a,a))

  for i in range(a):
    for j in range(a):
      terrain = random.random()
      
      if terrain < 0.2:
        env_terrains[i, j] = 5 # Flat terrain with p = 0.2
      elif terrain < 0.5:
        env_terrains[i, j] = 10 # Hilly terrain with p = 0.3
      elif terrain < 0.8:
        env_terrains[i, j] = 15 # Forested terrain with p = 0.3
      else:
        env_terrains[i, j] = 20 # Maze of caves with p = 0.2
  
  target_location = place_target(env_terrains)
  environment = (env_terrains, target_location)
  return environment

# %%
def display_grid(environment):
  env_grid = environment[0]
  target_location = environment[1]

  plt.figure(figsize = (8, 8))
  color_list = ['white', 'brown', 'green', 'gray']
  palette = sns.color_palette(color_list)
  ax = sns.heatmap(env_grid, annot = True,  linewidths = 0.01, linecolor = 'darkgray', cbar = False, xticklabels = True, yticklabels = True)
  ax.add_patch(Rectangle((target_location[1], target_location[0]), 1, 1, fill= False, capstyle = 'projecting', edgecolor='gold', linewidth = 4))
  plt.text(target_location[1] + 0.5, target_location[0] + 0.5, 'x', horizontalalignment = 'center', verticalalignment = 'center', fontsize = 30, color = 'gold')
  b, t = plt.ylim() # discover the values for bottom and top
  b += 0.5 # Add 0.5 to the bottom
  t -= 0.5 # Subtract 0.5 from the top
  plt.ylim(b, t) # update the ylim(bottom, top) values
  plt.show()

# %%
def search_cell(environment, cell):

  env_grid = environment[0]
  target_location = environment[1]

  if cell != target_location:
    return False

  else:
    if env_grid[cell] == 5:
      if random.random() < 0.9:
        return True
    elif env_grid[cell] == 10:
      if random.random() < 0.7:
        return True
    elif env_grid[cell] == 15:
      if random.random() < 0.3:
        return True
    elif env_grid[cell] == 20:
      if random.random() < 0.1:
        return True
    return False

# %% [markdown]
# ## Agent:

# %% [markdown]
# Decision rules - based on belief map and false negative rate of terrain of the cell:

# %%
def rule_1(belief_map):
  cell_index = np.unravel_index(np.argmax(belief_map, axis=None), belief_map.shape)
  return cell_index

# %%
def rule_2(environment, belief_map, false_negative_rate):
  
  false_negative_matrix = environment[0]/5
  for x in range(1,5):
   false_negative_matrix[false_negative_matrix == x] = (1 - false_negative_rate[x-1])

  new_probability = np.multiply(false_negative_matrix, belief_map)
  cell_index = np.unravel_index(np.random.choice(np.flatnonzero(belief_map == belief_map.max())), belief_map.shape)
  return cell_index

# %% [markdown]
# Function which updates the agent's belief of all the cells (belief of finding the target in the cell) whenever a cell is explored and the target is not found in the cell.

# %%
def update_belief(environment, prior_belief_map, cell_opened, false_negative_rate):
    
    dim = environment[0].shape[0]
    terrain = np.int(environment[0][cell_opened]/5)-1
    false_negative_cell_opened = false_negative_rate[terrain]
    denominator = 0
    
    for i in range(dim):
      for j in range(dim):
        cell = (i,j)
        if(cell_opened == cell):
          p = false_negative_cell_opened
        else:
          p = 1
        denominator = denominator + (prior_belief_map[cell] * p)
 
    #print(denominator)
    update_belief_map = prior_belief_map/denominator
    update_belief_map[cell_opened] = update_belief_map[cell_opened] * false_negative_cell_opened

    return update_belief_map

# %%
def agent(environment,rule_number):

  env_grid = environment[0]
  a = env_grid.shape[0]

  initial_belief = 1/(a*a)
  belief_map = np.full((a,a), initial_belief)

  false_negative_rate = [0.1, 0.3, 0.7, 0.9]
  num_of_searches = 0

  while(True):

    num_of_searches = num_of_searches + 1
    if rule_number == 0:
      # Rule 1 approach to select the cell
      cell = rule_1(belief_map)
    else:
      # Rule 2 approach to select the cell
      cell = rule_2(environment, belief_map, false_negative_rate)

    print("----UPDATED BELIEF MAP ----")
    sns.heatmap(belief_map, linewidths=0.2, cmap="Blues", )
    plt.text(cell[1] + 0.5, cell[0] + 0.5, 'x', horizontalalignment = 'center', verticalalignment = 'center', fontsize = 30, color = 'red')
    plt.title("Belief map update - Moving Target")
    fig = plt.gcf()
    plt.show()
    #fig.savefig('bonus_belief_'+str(num_of_searches))
    
    # Explore the selected cell
    is_target = search_cell(environment, cell)

    if(is_target):
      print("Success!")
      print("num_searches = ", num_of_searches)
      return num_of_searches
    else:
      belief_map = update_belief(environment, belief_map, cell, false_negative_rate)

# %% [markdown]
# Testing the agent:

# %%
a = 50
environment = generate_environment(a)
display_grid(environment)
start_time = time.time()
agent(environment,1)
print("Time:", time.time()- start_time)
# Out:
# Terrain of Target: 1
# Success!
# num_searches =  1160
# Time: 2.3542914390563965

# %%
a = 5
environment = generate_environment(a)
display_grid(environment)
start_time = time.time()
agent(environment,1)
print("Time:", time.time()- start_time)
# Out:
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# ----UPDATED BELIEF MAP ----
# Success!
# num_searches =  18
# Time: 3.9892776012420654

# %% [markdown]
# ### Analysis:
#
# Analysing performance of Rule 1 and Rule 2 on the same map (with target location changing each time) and on multiple maps (different environments each time).

# %%
def performance_analysis(num_trials, dim):

  total_searches_1 = 0
  total_searches_2 = 0

  environment = generate_environment(dim)
  env_grid = environment[0]

  false_negative_rate = [0.1, 0.3, 0.7, 0.9]

  for i in range(num_trials):

    target_location = place_target(env_grid)
    environment = (env_grid, target_location)

    num_of_searches_1 = agent(environment,0)  # Rule 1
    num_of_searches_2 = agent(environment,1)  # Rule 2
    
    total_searches_1 = total_searches_1 + num_of_searches_1
    total_searches_2 = total_searches_2 + num_of_searches_2

  avg_searches_1 = total_searches_1/num_trials
  avg_searches_2 = total_searches_2/num_trials

  print("Average number of searches if Rule 1 is used: " + str(avg_searches_1))
  print("Average number of searches if Rule 2 is used: " + str(avg_searches_2))

# %%
performance_analysis(50,50)
# Out:
# Average number of searches if Rule 1 is used: 4836.66
# Average number of searches if Rule 2 is used: 3974.22

# %%
def multiple_maps(num_trials,a):

  total_searches_1 = 0
  total_searches_2 = 0

  false_negative_rate = [0.1, 0.3, 0.7, 0.9]

  for i in range(num_trials):
      environment = generate_environment(a)
      env_grid = environment[0]
      target_location = place_target(env_grid)

      initial_belief = 1/(a * a)
      belief_map = np.full((a, a), initial_belief)

      num_of_searches_1 = rule_1_approach(environment,belief_map,false_negative_rate)
      num_of_searches_2 = rule_2_approach(environment,belief_map,false_negative_rate)
      
      total_searches_1 = total_searches_1 + num_of_searches_1
      total_searches_2 = total_searches_2 + num_of_searches_2

  avg_searches_1 = total_searches_1/num_trials
  avg_searches_2 = total_searches_2/num_trials

  print("Average number of searches if Rule 1 is used: " + str(avg_searches_1))
  print("Average number of searches if Rule 2 is used: " + str(avg_searches_2))

# %%
multiple_maps(50,50)
# Out:
# Average number of searches if Rule 1 is used: 5033.96
# Average number of searches if Rule 2 is used: 4147.1

# %% [markdown]
# #### Terrain wise analysis of Rule 1 and Rule 2:

# %%
## Function to generate environment with target in a particular terrain

def assign_terrain(a,terrain_type):

  # Terrain Type: 0 - Flat, 1 - Hilly, 2 - Forested, 3 - Caves
  env_terrains = np.zeros((a,a))

  flat_list = []
  hilly_list = []
  forest_list = []
  cave_list = []

  for i in range(a):
    for j in range(a):
      terrain = random.random()
      if terrain < 0.2:
        env_terrains[i, j] = 5 # Flat terrain with p = 0.2
        flat_list.append((i,j))
      elif terrain < 0.5:
        env_terrains[i, j] = 10 # Hilly terrain with p = 0.3
        hilly_list.append((i,j))
      elif terrain < 0.8:
        env_terrains[i, j] = 15 # Forested terrain with p = 0.3
        forest_list.append((i,j))
      else:
        env_terrains[i, j] = 20 # Maze of caves with p = 0.2
        cave_list.append((i,j))
  
  if terrain_type == 0:
    n = len(flat_list)
    index = random.randint(0,n-1)
    target_location = flat_list[index]
  elif terrain_type == 1:
    n = len(hilly_list)
    index = random.randint(0,n-1)
    target_location = hilly_list[index]
  elif terrain_type == 2:
    n = len(forest_list)
    index = random.randint(0,n-1)
    target_location = forest_list[index]
  elif terrain_type == 3:
    n = len(cave_list)
    index = random.randint(0,n-1)
    target_location = cave_list[index]

  environment = (env_terrains, target_location)
  num_terrains = [len(flat_list), len(hilly_list), len(forest_list), len(cave_list)]
  return environment, num_terrains

# %% [markdown]
# Functions to validate the performance of rule 1 and rule 2:

# %%
def check_rule_1(num_trials, dim):

  false_negative_rate = [0.1, 0.3, 0.7, 0.9]

  average_list = np.full((4), 0)
  average_matrix = np.full((4, 4), 0)
  rule_performance = np.full((4), 0)

  for ter in range(4):
    print("----------------------------")
    print("Terrain " + str(ter))
    for i in range(num_trials):
      print("----------------------------")
      print("Iteration " + str(i) + ":")
      
      environment, num_terrains = assign_terrain(dim, ter)
      env_grid = environment[0]
      visits = np.full((4), 0)

      is_target_2 = False
      num_of_searches_2 = 0
      initial_belief = 1/(dim * dim)
      belief_map = np.full((dim, dim), initial_belief)

      # Rule 1
      while(True):
        num_of_searches_2 = num_of_searches_2 + 1
        cell = rule_1(belief_map)
        terrain = int((env_grid[cell]/5) - 1)
        visits[terrain] += 1
        is_target_2 = search_cell(environment, cell)
        if(is_target_2):
          break
        else:
          belief_map = update_belief(environment, belief_map, cell , false_negative_rate)
      
      print("Cells per terrain: " + str(num_terrains))
      print("Visits per terrain: " + str(visits))
      print("Number of searches: " + str(num_of_searches_2))
      average_list += visits
      rule_performance[ter] += num_of_searches_2
    
    average_list = average_list/num_trials
    print("Average visits per terrain: " + str(average_list))
    for j in range(4):
      average_matrix[ter][j] += average_list[j]

  print("Average Matrix: ")
  pp.pprint(average_matrix)
  return rule_performance

# %%
 def check_rule_2(num_trials, dim):

  false_negative_rate = [0.1, 0.3, 0.7, 0.9]

  average_list = np.full((4), 0)
  average_matrix = np.full((4, 4), 0)
  rule_performance = np.full((4), 0)
  
  for ter in range(4):
    print("----------------------------")
    print("Terrain " + str(ter))
    for i in range(num_trials):
      print("----------------------------")
      print("Iteration " + str(i) + ":")
      
      environment, num_terrains = assign_terrain(dim, ter)
      env_grid = environment[0]
      visits = np.full((4), 0)

      is_target_2 = False
      num_of_searches_2 = 0
      initial_belief = 1/(dim * dim)
      belief_map = np.full((dim, dim), initial_belief)

      # Rule 1
      while(True):
        num_of_searches_2 = num_of_searches_2 + 1
        cell = rule_2(environment, belief_map, false_negative_rate)
        terrain = int((env_grid[cell]/5) - 1)
        visits[terrain] += 1
        is_target_2 = search_cell(environment, cell)
        if(is_target_2):
          break
        else:
          belief_map = update_belief(environment, belief_map, cell , false_negative_rate)
      
      print("Cells per terrain: " + str(num_terrains))
      print("Visits per terrain: " + str(visits))
      print("Number of searches: " + str(num_of_searches_2))
      average_list += visits
      rule_performance[ter] += num_of_searches_2
    
    average_list = average_list/num_trials
    print("Average visits per terrain: " + str(average_list))
    for j in range(4):
      average_matrix[ter][j] += average_list[j]

  print("Average Matrix: ")
  pp.pprint(average_matrix)
  return rule_performance

# %%
average_perf_1 = np.full(4,0)
average_perf_2 = np. full(4,0)
x_text_dict = [ "Flat", "Hilly", "Forested", "Caves"]
  
for i in range(10):  
  performance_rule1 = check_rule_1(20, 50)
  print("Rule 1 performance: " + str(performance_rule1))
  average_perf_1 += performance_rule1
  plt.figure()
  sns.barplot(x_text_dict, list(performance_rule1))
  
  performance_rule2 = check_rule_2(50, 50)
  print("Rule 2 performance: " + str(performance_rule2))
  average_perf_2 += performance_rule2
  plt.figure()
  sns.barplot(x_text_dict, list(performance_rule2))

print("Average Rule 1 performance: " + str(average_perf_1/10))
print("Average Rule 2 performance: " + str(average_perf_2/10))
plt.figure()
sns.barplot(x_text_dict, list(average_perf_1))
plt.figure()
sns.barplot(x_text_dict, list(average_perf_2))
# Out:
# ----------------------------
# Terrain 0
# ----------------------------
# Iteration 0:
# Cells per terrain: [512, 746, 723, 519]
# Visits per terrain: [302 461 458 341]
# Number of searches: 1562
# ----------------------------
# Iteration 1:
# Cells per terrain: [515, 749, 754, 482]
# Visits per terrain: [386 582 592 366]
# Number of searches: 1926
# ----------------------------
# Iteration 2:
# Cells per terrain: [497, 726, 781, 496]
# Visits per terrain: [485 699 756 478]
# Number of searches: 2418
# ----------------------------
# Iteration 3:
# Cells per terrain: [507, 729, 774, 490]
# Visits per terrain: [  624  1458  5418 10780]
# Number of searches: 18280
# ----------------------------
# Iteration 4:
# Cells per terrain: [472, 774, 748, 506]
# Visits per terrain: [ 85 164 146 109]
# Number of searches: 504
# ----------------------------
# Iteration 5:
# Cells per terrain: [500, 751, 769, 480]
# Visits per terrain: [129 192 196 115]
# Number of searches: 632
# ----------------------------
# Iteration 6:
# Cells per terrain: [519, 758, 739, 484]
# Visits per terrain: [121 179 157 106]
# Number of searches: 563
# ----------------------------
# Iteration 7:
# Cells per terrain: [508, 754, 762, 476]
# Visits per terrain: [146 227 209 124]
# Number of searches: 706
# ----------------------------
# Iteration 8:
# Cells per terrain: [509, 749, 746, 496]
# Visits per terrain: [155 206 204 146]
# Number of searches: 711
# ----------------------------
# Iteration 9:
# Cells per terrain: [515, 761, 736, 488]
# Visits per terrain: [302 476 440 284]
# Number of searches: 1502
# ----------------------------
# Iteration 10:
# Cells per terrain: [491, 777, 722, 510]
# Visits per terrain: [  916  1554  5054 11220]
# Number of searches: 18744
# ----------------------------
# Iteration 11:
# Cells per terrain: [489, 726, 805, 480]
# Visits per terrain: [281 408 469 251]
# Number of searches: 1409
# ----------------------------
# Iteration 12:
# Cells per terrain: [507, 752, 750, 491]
# Visits per terrain: [313 471 508 331]
# Number of searches: 1623
# ----------------------------
# Iteration 13:
# Cells per terrain: [475, 753, 766, 506]
# Visits per terrain: [390 611 645 398]
# Number of searches: 2044
# ----------------------------
# Iteration 14:
# Cells per terrain: [508, 734, 730, 528]
# Visits per terrain: [  987  1468  5110 11616]
# Number of searches: 19181
# ----------------------------
# Iteration 15:
# Cells per terrain: [511, 720, 753, 516]
# Visits per terrain: [298 406 448 277]
# Number of searches: 1429
# ----------------------------
# Iteration 16:
# Cells per terrain: [525, 780, 717, 478]
# Visits per terrain: [427 631 604 399]
# Number of searches: 2061
# ----------------------------
# Iteration 17:
# Cells per terrain: [464, 753, 748, 535]
# Visits per terrain: [  471  1506  5236 11770]
# Number of searches: 18983
# ----------------------------
# Iteration 18:
# Cells per terrain: [478, 799, 749, 474]
# Visits per terrain: [409 688 645 413]
# Number of searches: 2155
# ----------------------------
# Iteration 19:
# Cells per terrain: [491, 771, 739, 499]
# Visits per terrain: [ 71 139 134  86]
# Number of searches: 430
# Average visits per terrain: [ 364.9   626.3  1371.45 2480.5 ]
# ----------------------------
# Terrain 1
# ----------------------------
# Iteration 0:
# Cells per terrain: [530, 716, 723, 531]
# Visits per terrain: [ 60  92 102  64]
# Number of searches: 318
# ----------------------------
# Iteration 1:
# Cells per terrain: [483, 764, 766, 487]
# Visits per terrain: [ 483 1316 3064 5844]
# Number of searches: 10707
# ----------------------------
# Iteration 2:
# Cells per terrain: [498, 756, 797, 449]
# Visits per terrain: [ 498 1271 3188 5388]
# Number of searches: 10345
# ----------------------------
# Iteration 3:
# Cells per terrain: [481, 810, 728, 481]
# Visits per terrain: [234 414 354 259]
# Number of searches: 1261
# ----------------------------
# Iteration 4:
# Cells per terrain: [494, 760, 743, 503]
# Visits per terrain: [56 82 81 54]
# Number of searches: 273
# ----------------------------
# Iteration 5:
# Cells per terrain: [490, 740, 775, 495]
# Visits per terrain: [ 490 1264 3100 5940]
# Number of searches: 10794
# ----------------------------
# Iteration 6:
# Cells per terrain: [535, 755, 698, 512]
# Visits per terrain: [254 341 328 240]
# Number of searches: 1163
# ----------------------------
# Iteration 7:
# Cells per terrain: [497, 723, 764, 516]
# Visits per terrain: [  994  2763  8404 18060]
# Number of searches: 30221
# ----------------------------
# Iteration 8:
# Cells per terrain: [531, 752, 715, 502]
# Visits per terrain: [511 728 698 484]
# Number of searches: 2421
# ----------------------------
# Iteration 9:
# Cells per terrain: [495, 748, 744, 513]
# Visits per terrain: [419 635 620 431]
# Number of searches: 2105
# ----------------------------
# Iteration 10:
# Cells per terrain: [480, 737, 764, 519]
# Visits per terrain: [430 673 677 476]
# Number of searches: 2256
# ----------------------------
# Iteration 11:
# Cells per terrain: [463, 765, 794, 478]
# Visits per terrain: [  926  2668  8734 16730]
# Number of searches: 29058
# ----------------------------
# Iteration 12:
# Cells per terrain: [515, 748, 753, 484]
# Visits per terrain: [505 735 746 473]
# Number of searches: 2459
# ----------------------------
# Iteration 13:
# Cells per terrain: [483, 753, 741, 523]
# Visits per terrain: [46 61 64 46]
# Number of searches: 217
# ----------------------------
# Iteration 14:
# Cells per terrain: [511, 745, 764, 480]
# Visits per terrain: [260 404 378 261]
# Number of searches: 1303
# ----------------------------
# Iteration 15:
# Cells per terrain: [534, 729, 714, 523]
# Visits per terrain: [244 351 339 248]
# Number of searches: 1182
# ----------------------------
# Iteration 16:
# Cells per terrain: [521, 740, 725, 514]
# Visits per terrain: [ 521  826 2900 6168]
# Number of searches: 10415
# ----------------------------
# Iteration 17:
# Cells per terrain: [507, 742, 771, 480]
# Visits per terrain: [356 505 500 343]
# Number of searches: 1704
# ----------------------------
# Iteration 18:
# Cells per terrain: [488, 726, 784, 502]
# Visits per terrain: [351 514 560 364]
# Number of searches: 1789
# ----------------------------
# Iteration 19:
# Cells per terrain: [479, 750, 779, 492]
# Visits per terrain: [ 73 116 118  71]
# Number of searches: 378
# Average visits per terrain: [ 403.795   819.265  1816.3225 3221.225 ]
# ----------------------------
# Terrain 2
# ----------------------------
# Iteration 0:
# Cells per terrain: [510, 793, 709, 488]
# Visits per terrain: [ 510  793 2183 5368]
# Number of searches: 8854
# ----------------------------
# Iteration 1:
# Cells per terrain: [491, 789, 720, 500]
# Visits per terrain: [172 268 248 187]
# Number of searches: 875
# ----------------------------
# Iteration 2:
# Cells per terrain: [508, 757, 746, 489]
# Visits per terrain: [ 508  757 1457 1956]
# Number of searches: 4678
# ----------------------------
# Iteration 3:
# Cells per terrain: [485, 708, 764, 543]
# Visits per terrain: [  485  1416  4684 11403]
# Number of searches: 17988
# ----------------------------
# Iteration 4:
# Cells per terrain: [487, 743, 749, 521]
# Visits per terrain: [ 487  743 1198 2084]
# Number of searches: 4512
# ----------------------------
# Iteration 5:
# Cells per terrain: [464, 746, 764, 526]
# Visits per terrain: [  928  2238  8050 17884]
# Number of searches: 29100
# ----------------------------
# Iteration 6:
# Cells per terrain: [484, 765, 774, 477]
# Visits per terrain: [437 694 694 429]
# Number of searches: 2254
# ----------------------------
# Iteration 7:
# Cells per terrain: [514, 758, 719, 509]
# Visits per terrain: [ 514  758 1921 3563]
# Number of searches: 6756
# ----------------------------
# Iteration 8:
# Cells per terrain: [447, 808, 735, 510]
# Visits per terrain: [ 447  808 1648 3570]
# Number of searches: 6473
# ----------------------------
# Iteration 9:
# Cells per terrain: [481, 756, 770, 493]
# Visits per terrain: [29 54 33 28]
# Number of searches: 144
# ----------------------------
# Iteration 10:
# Cells per terrain: [513, 761, 746, 480]
# Visits per terrain: [193 289 285 184]
# Number of searches: 951
# ----------------------------
# Iteration 11:
# Cells per terrain: [444, 815, 733, 508]
# Visits per terrain: [ 444  815 2302 5588]
# Number of searches: 9149
# ----------------------------
# Iteration 12:
# Cells per terrain: [490, 760, 743, 507]
# Visits per terrain: [ 490  760 1315 2028]
# Number of searches: 4593
# ----------------------------
# Iteration 13:
# Cells per terrain: [484, 725, 758, 533]
# Visits per terrain: [ 484  725 1289 2132]
# Number of searches: 4630
# ----------------------------
# Iteration 14:
# Cells per terrain: [492, 745, 779, 484]
# Visits per terrain: [ 492  745 1579 3388]
# Number of searches: 6204
# ----------------------------
# Iteration 15:
# Cells per terrain: [530, 735, 727, 508]
# Visits per terrain: [ 530  735 1288 2032]
# Number of searches: 4585
# ----------------------------
# Iteration 16:
# Cells per terrain: [518, 723, 744, 515]
# Visits per terrain: [ 518  723  995 2060]
# Number of searches: 4296
# ----------------------------
# Iteration 17:
# Cells per terrain: [489, 764, 787, 460]
# Visits per terrain: [ 489 1528 4561 7820]
# Number of searches: 14398
# ----------------------------
# Iteration 18:
# Cells per terrain: [486, 733, 744, 537]
# Visits per terrain: [460 698 695 512]
# Number of searches: 2365
# ----------------------------
# Iteration 19:
# Cells per terrain: [502, 757, 792, 449]
# Visits per terrain: [472 702 747 417]
# Number of searches: 2338
# Average visits per terrain: [ 474.63975   853.41325  1949.416125 3792.71125 ]
# ----------------------------
# Terrain 3
# ----------------------------
# Iteration 0:
# Cells per terrain: [475, 727, 819, 479]
# Visits per terrain: [ 475 1454 3276 6007]
# Number of searches: 11212
# ----------------------------
# Iteration 1:
# Cells per terrain: [465, 783, 745, 507]
# Visits per terrain: [ 465  783 1490 3301]
# Number of searches: 6039
# ----------------------------
# Iteration 2:
# Cells per terrain: [485, 779, 784, 452]
# Visits per terrain: [ 485  779  784 1323]
# Number of searches: 3371
# ----------------------------
# Iteration 3:
# Cells per terrain: [500, 745, 754, 501]
# Visits per terrain: [ 500 1490 4524 9649]
# Number of searches: 16163
# ----------------------------
# Iteration 4:
# Cells per terrain: [499, 755, 729, 517]
# Visits per terrain: [  998  1510  5103 11854]
# Number of searches: 19465
# ----------------------------
# Iteration 5:
# Cells per terrain: [533, 722, 766, 479]
# Visits per terrain: [ 533 1444 3064 6193]
# Number of searches: 11234
# ----------------------------
# Iteration 6:
# Cells per terrain: [492, 755, 760, 493]
# Visits per terrain: [ 492  755 2280 4760]
# Number of searches: 8287
# ----------------------------
# Iteration 7:
# Cells per terrain: [500, 742, 770, 488]
# Visits per terrain: [ 500  742 1540 2432]
# Number of searches: 5214
# ----------------------------
# Iteration 8:
# Cells per terrain: [506, 728, 780, 486]
# Visits per terrain: [ 506  728 1560 2375]
# Number of searches: 5169
# ----------------------------
# Iteration 9:
# Cells per terrain: [525, 717, 757, 501]
# Visits per terrain: [ 525  717 2271 5373]
# Number of searches: 8886
# ----------------------------
# Iteration 10:
# Cells per terrain: [472, 733, 769, 526]
# Visits per terrain: [472 733 769 800]
# Number of searches: 2774
# ----------------------------
# Iteration 11:
# Cells per terrain: [482, 763, 735, 520]
# Visits per terrain: [298 454 466 302]
# Number of searches: 1520
# ----------------------------
# Iteration 12:
# Cells per terrain: [502, 759, 707, 532]
# Visits per terrain: [ 502  759 1414 3656]
# Number of searches: 6331
# ----------------------------
# Iteration 13:
# Cells per terrain: [513, 723, 773, 491]
# Visits per terrain: [ 513 1446 3865 7281]
# Number of searches: 13105
# ----------------------------
# Iteration 14:
# Cells per terrain: [483, 749, 781, 487]
# Visits per terrain: [483 749 781 954]
# Number of searches: 2967
# ----------------------------
# Iteration 15:
# Cells per terrain: [488, 738, 767, 507]
# Visits per terrain: [ 488  738  767 1729]
# Number of searches: 3722
# ----------------------------
# Iteration 16:
# Cells per terrain: [477, 761, 739, 523]
# Visits per terrain: [ 477  761  739 1922]
# Number of searches: 3899
# ----------------------------
# Iteration 17:
# Cells per terrain: [489, 735, 773, 503]
# Visits per terrain: [489 735 773 696]
# Number of searches: 2693
# ----------------------------
# Iteration 18:
# Cells per terrain: [498, 779, 721, 502]
# Visits per terrain: [ 498 1558 2884 6564]
# Number of searches: 11504
# ----------------------------
# Iteration 19:
# Cells per terrain: [493, 737, 770, 500]
# Visits per terrain: [ 493  737  770 1759]
# Number of searches: 3759
# Average visits per terrain: [ 533.3319875   996.2706625  2053.47080625 4136.1355625 ]
# Average Matrix:
# array([[ 364,  626, 1371, 2480],
#        [ 403,  819, 1816, 3221],
#        [ 474,  853, 1949, 3792],
#        [ 533,  996, 2053, 4136]])
# Rule 1 performance: [ 96863 120369 135143 147314]
# ----------------------------
# Terrain 0
# ----------------------------
# Iteration 0:
# Cells per terrain: [488, 747, 742, 523]
# Visits per terrain: [402   0   0   0]
# Number of searches: 402
# ----------------------------
# Iteration 1:
# Cells per terrain: [493, 764, 737, 506]
# Visits per terrain: [227   0   0   0]
# Number of searches: 227
# ----------------------------
# Iteration 2:
# Cells per terrain: [542, 770, 707, 481]
# Visits per terrain: [ 684 1540 2828  878]
# Number of searches: 5930
# ----------------------------
# Iteration 3:
# Cells per terrain: [493, 716, 764, 527]
# Visits per terrain: [36  0  0  0]
# Number of searches: 36
# ----------------------------
# Iteration 4:
# Cells per terrain: [482, 736, 756, 526]
# Visits per terrain: [193   0   0   0]
# Number of searches: 193
# ----------------------------
# Iteration 5:
# Cells per terrain: [467, 752, 785, 496]
# Visits per terrain: [61  0  0  0]
# Number of searches: 61
# ----------------------------
# Iteration 6:
# Cells per terrain: [481, 771, 753, 495]
# Visits per terrain: [9 0 0 0]
# Number of searches: 9
# ----------------------------
# Iteration 7:
# Cells per terrain: [489, 764, 763, 484]
# Visits per terrain: [233   0   0   0]
# Number of searches: 233
# ----------------------------
# Iteration 8:
# Cells per terrain: [466, 749, 763, 522]
# Visits per terrain: [ 886 1498 3052 1044]
# Number of searches: 6480
# ----------------------------
# Iteration 9:
# Cells per terrain: [509, 743, 761, 487]
# Visits per terrain: [79  0  0  0]
# Number of searches: 79
# ----------------------------
# Iteration 10:
# Cells per terrain: [529, 712, 751, 508]
# Visits per terrain: [116   0   0   0]
# Number of searches: 116
# ----------------------------
# Iteration 11:
# Cells per terrain: [511, 765, 767, 457]
# Visits per terrain: [320   0   0   0]
# Number of searches: 320
# ----------------------------
# Iteration 12:
# Cells per terrain: [487, 793, 729, 491]
# Visits per terrain: [47  0  0  0]
# Number of searches: 47
# ----------------------------
# Iteration 13:
# Cells per terrain: [503, 757, 757, 483]
# Visits per terrain: [449   0   0   0]
# Number of searches: 449
# ----------------------------
# Iteration 14:
# Cells per terrain: [477, 752, 758, 513]
# Visits per terrain: [110   0   0   0]
# Number of searches: 110
# ----------------------------
# Iteration 15:
# Cells per terrain: [491, 731, 765, 513]
# Visits per terrain: [274   0   0   0]
# Number of searches: 274
# ----------------------------
# Iteration 16:
# Cells per terrain: [486, 761, 727, 526]
# Visits per terrain: [ 943 1522 2908  527]
# Number of searches: 5900
# ----------------------------
# Iteration 17:
# Cells per terrain: [498, 754, 729, 519]
# Visits per terrain: [73  0  0  0]
# Number of searches: 73
# ----------------------------
# Iteration 18:
# Cells per terrain: [508, 774, 741, 477]
# Visits per terrain: [443   0   0   0]
# Number of searches: 443
# ----------------------------
# Iteration 19:
# Cells per terrain: [497, 791, 733, 479]
# Visits per terrain: [ 676 1582 2932  958]
# Number of searches: 6148
# ----------------------------
# Iteration 20:
# Cells per terrain: [504, 726, 762, 508]
# Visits per terrain: [110   0   0   0]
# Number of searches: 110
# ----------------------------
# Iteration 21:
# Cells per terrain: [507, 761, 744, 488]
# Visits per terrain: [399   0   0   0]
# Number of searches: 399
# ----------------------------
# Iteration 22:
# Cells per terrain: [534, 736, 754, 476]
# Visits per terrain: [ 1285  2944  7540 10948]
# Number of searches: 22717
# ----------------------------
# Iteration 23:
# Cells per terrain: [510, 679, 786, 525]
# Visits per terrain: [292   0   0   0]
# Number of searches: 292
# ----------------------------
# Iteration 24:
# Cells per terrain: [530, 733, 760, 477]
# Visits per terrain: [122   0   0   0]
# Number of searches: 122
# ----------------------------
# Iteration 25:
# Cells per terrain: [509, 740, 748, 503]
# Visits per terrain: [389   0   0   0]
# Number of searches: 389
# ----------------------------
# Iteration 26:
# Cells per terrain: [492, 762, 709, 537]
# Visits per terrain: [82  0  0  0]
# Number of searches: 82
# ----------------------------
# Iteration 27:
# Cells per terrain: [524, 728, 753, 495]
# Visits per terrain: [112   0   0   0]
# Number of searches: 112
# ----------------------------
# Iteration 28:
# Cells per terrain: [481, 795, 705, 519]
# Visits per terrain: [74  0  0  0]
# Number of searches: 74
# ----------------------------
# Iteration 29:
# Cells per terrain: [492, 740, 744, 524]
# Visits per terrain: [321   0   0   0]
# Number of searches: 321
# ----------------------------
# Iteration 30:
# Cells per terrain: [510, 721, 773, 496]
# Visits per terrain: [315   0   0   0]
# Number of searches: 315
# ----------------------------
# Iteration 31:
# Cells per terrain: [507, 749, 731, 513]
# Visits per terrain: [495   0   0   0]
# Number of searches: 495
# ----------------------------
# Iteration 32:
# Cells per terrain: [541, 738, 712, 509]
# Visits per terrain: [375   0   0   0]
# Number of searches: 375
# ----------------------------
# Iteration 33:
# Cells per terrain: [527, 741, 733, 499]
# Visits per terrain: [326   0   0   0]
# Number of searches: 326
# ----------------------------
# Iteration 34:
# Cells per terrain: [479, 727, 778, 516]
# Visits per terrain: [294   0   0   0]
# Number of searches: 294
# ----------------------------
# Iteration 35:
# Cells per terrain: [490, 786, 756, 468]
# Visits per terrain: [152   0   0   0]
# Number of searches: 152
# ----------------------------
# Iteration 36:
# Cells per terrain: [514, 736, 738, 512]
# Visits per terrain: [372   0   0   0]
# Number of searches: 372
# ----------------------------
# Iteration 37:
# Cells per terrain: [465, 810, 705, 520]
# Visits per terrain: [359   0   0   0]
# Number of searches: 359
# ----------------------------
# Iteration 38:
# Cells per terrain: [506, 751, 746, 497]
# Visits per terrain: [490   0   0   0]
# Number of searches: 490
# ----------------------------
# Iteration 39:
# Cells per terrain: [515, 748, 752, 485]
# Visits per terrain: [336   0   0   0]
# Number of searches: 336
# ----------------------------
# Iteration 40:
# Cells per terrain: [501, 730, 765, 504]
# Visits per terrain: [150   0   0   0]
# Number of searches: 150
# ----------------------------
# Iteration 41:
# Cells per terrain: [507, 714, 776, 503]
# Visits per terrain: [343   0   0   0]
# Number of searches: 343
# ----------------------------
# Iteration 42:
# Cells per terrain: [490, 737, 789, 484]
# Visits per terrain: [45  0  0  0]
# Number of searches: 45
# ----------------------------
# Iteration 43:
# Cells per terrain: [507, 732, 752, 509]
# Visits per terrain: [ 870 1464 3008 1018]
# Number of searches: 6360
# ----------------------------
# Iteration 44:
# Cells per terrain: [519, 754, 741, 486]
# Visits per terrain: [124   0   0   0]
# Number of searches: 124
# ----------------------------
# Iteration 45:
# Cells per terrain: [486, 754, 728, 532]
# Visits per terrain: [222   0   0   0]
# Number of searches: 222
# ----------------------------
# Iteration 46:
# Cells per terrain: [507, 715, 810, 468]
# Visits per terrain: [ 801 1430 3240  936]
# Number of searches: 6407
# ----------------------------
# Iteration 47:
# Cells per terrain: [523, 727, 754, 496]
# Visits per terrain: [2 0 0 0]
# Number of searches: 2
# ----------------------------
# Iteration 48:
# Cells per terrain: [497, 791, 721, 491]
# Visits per terrain: [188   0   0   0]
# Number of searches: 188
# ----------------------------
# Iteration 49:
# Cells per terrain: [520, 732, 769, 479]
# Visits per terrain: [16  0  0  0]
# Number of searches: 16
# Average visits per terrain: [314.44 239.6  510.16 326.18]
# ----------------------------
# Terrain 1
# ----------------------------
# Iteration 0:
# Cells per terrain: [507, 769, 710, 514]
# Visits per terrain: [ 507 1018  710    0]
# Number of searches: 2235
# ----------------------------
# Iteration 1:
# Cells per terrain: [488, 745, 758, 509]
# Visits per terrain: [488  61   0   0]
# Number of searches: 549
# ----------------------------
# Iteration 2:
# Cells per terrain: [497, 762, 754, 487]
# Visits per terrain: [ 497  917 1332    0]
# Number of searches: 2746
# ----------------------------
# Iteration 3:
# Cells per terrain: [510, 759, 732, 499]
# Visits per terrain: [510 186   0   0]
# Number of searches: 696
# ----------------------------
# Iteration 4:
# Cells per terrain: [484, 753, 721, 542]
# Visits per terrain: [484 126   0   0]
# Number of searches: 610
# ----------------------------
# Iteration 5:
# Cells per terrain: [496, 767, 745, 492]
# Visits per terrain: [496 763   0   0]
# Number of searches: 1259
# ----------------------------
# Iteration 6:
# Cells per terrain: [489, 711, 760, 540]
# Visits per terrain: [ 489 1194  971    0]
# Number of searches: 2654
# ----------------------------
# Iteration 7:
# Cells per terrain: [494, 766, 723, 517]
# Visits per terrain: [494 561   0   0]
# Number of searches: 1055
# ----------------------------
# Iteration 8:
# Cells per terrain: [495, 768, 736, 501]
# Visits per terrain: [ 495 1136 1472    0]
# Number of searches: 3103
# ----------------------------
# Iteration 9:
# Cells per terrain: [510, 766, 733, 491]
# Visits per terrain: [510  41   0   0]
# Number of searches: 551
# ----------------------------
# Iteration 10:
# Cells per terrain: [499, 753, 758, 490]
# Visits per terrain: [499  89   0   0]
# Number of searches: 588
# ----------------------------
# Iteration 11:
# Cells per terrain: [491, 715, 790, 504]
# Visits per terrain: [491 861 790   0]
# Number of searches: 2142
# ----------------------------
# Iteration 12:
# Cells per terrain: [479, 733, 738, 550]
# Visits per terrain: [479 168   0   0]
# Number of searches: 647
# ----------------------------
# Iteration 13:
# Cells per terrain: [523, 742, 748, 487]
# Visits per terrain: [523 252   0   0]
# Number of searches: 775
# ----------------------------
# Iteration 14:
# Cells per terrain: [529, 684, 795, 492]
# Visits per terrain: [529 327   0   0]
# Number of searches: 856
# ----------------------------
# Iteration 15:
# Cells per terrain: [524, 723, 742, 511]
# Visits per terrain: [524 505   0   0]
# Number of searches: 1029
# ----------------------------
# Iteration 16:
# Cells per terrain: [470, 782, 728, 520]
# Visits per terrain: [470 108   0   0]
# Number of searches: 578
# ----------------------------
# Iteration 17:
# Cells per terrain: [487, 802, 719, 492]
# Visits per terrain: [487 738   0   0]
# Number of searches: 1225
# ----------------------------
# Iteration 18:
# Cells per terrain: [531, 720, 742, 507]
# Visits per terrain: [1062 1904 3710 2535]
# Number of searches: 9211
# ----------------------------
# Iteration 19:
# Cells per terrain: [503, 757, 713, 527]
# Visits per terrain: [503 246   0   0]
# Number of searches: 749
# ----------------------------
# Iteration 20:
# Cells per terrain: [457, 757, 766, 520]
# Visits per terrain: [457 598   0   0]
# Number of searches: 1055
# ----------------------------
# Iteration 21:
# Cells per terrain: [499, 739, 748, 514]
# Visits per terrain: [ 499 1012 1113    0]
# Number of searches: 2624
# ----------------------------
# Iteration 22:
# Cells per terrain: [504, 777, 721, 498]
# Visits per terrain: [504 273   0   0]
# Number of searches: 777
# ----------------------------
# Iteration 23:
# Cells per terrain: [484, 701, 778, 537]
# Visits per terrain: [484 547   0   0]
# Number of searches: 1031
# ----------------------------
# Iteration 24:
# Cells per terrain: [521, 716, 750, 513]
# Visits per terrain: [521 196   0   0]
# Number of searches: 717
# ----------------------------
# Iteration 25:
# Cells per terrain: [491, 750, 740, 519]
# Visits per terrain: [491 281   0   0]
# Number of searches: 772
# ----------------------------
# Iteration 26:
# Cells per terrain: [531, 741, 725, 503]
# Visits per terrain: [531 269   0   0]
# Number of searches: 800
# ----------------------------
# Iteration 27:
# Cells per terrain: [505, 764, 730, 501]
# Visits per terrain: [505 618   0   0]
# Number of searches: 1123
# ----------------------------
# Iteration 28:
# Cells per terrain: [504, 729, 792, 475]
# Visits per terrain: [504 658   0   0]
# Number of searches: 1162
# ----------------------------
# Iteration 29:
# Cells per terrain: [531, 727, 735, 507]
# Visits per terrain: [531 412   0   0]
# Number of searches: 943
# ----------------------------
# Iteration 30:
# Cells per terrain: [489, 775, 728, 508]
# Visits per terrain: [ 489  779 1179    0]
# Number of searches: 2447
# ----------------------------
# Iteration 31:
# Cells per terrain: [506, 741, 739, 514]
# Visits per terrain: [ 506 1177 1478    0]
# Number of searches: 3161
# ----------------------------
# Iteration 32:
# Cells per terrain: [511, 737, 747, 505]
# Visits per terrain: [511 624   0   0]
# Number of searches: 1135
# ----------------------------
# Iteration 33:
# Cells per terrain: [551, 706, 755, 488]
# Visits per terrain: [551 210   0   0]
# Number of searches: 761
# ----------------------------
# Iteration 34:
# Cells per terrain: [512, 737, 758, 493]
# Visits per terrain: [ 512 1286 1516    0]
# Number of searches: 3314
# ----------------------------
# Iteration 35:
# Cells per terrain: [525, 729, 770, 476]
# Visits per terrain: [ 1575  3588  9240 13328]
# Number of searches: 27731
# ----------------------------
# Iteration 36:
# Cells per terrain: [506, 800, 722, 472]
# Visits per terrain: [506   4   0   0]
# Number of searches: 510
# ----------------------------
# Iteration 37:
# Cells per terrain: [565, 731, 754, 450]
# Visits per terrain: [565 697   0   0]
# Number of searches: 1262
# ----------------------------
# Iteration 38:
# Cells per terrain: [494, 762, 733, 511]
# Visits per terrain: [494 532   0   0]
# Number of searches: 1026
# ----------------------------
# Iteration 39:
# Cells per terrain: [520, 731, 759, 490]
# Visits per terrain: [520 720   0   0]
# Number of searches: 1240
# ----------------------------
# Iteration 40:
# Cells per terrain: [457, 753, 784, 506]
# Visits per terrain: [457 647   0   0]
# Number of searches: 1104
# ----------------------------
# Iteration 41:
# Cells per terrain: [468, 736, 764, 532]
# Visits per terrain: [ 936 2813 6112 8512]
# Number of searches: 18373
# ----------------------------
# Iteration 42:
# Cells per terrain: [491, 756, 774, 479]
# Visits per terrain: [ 982 2597 6192 7664]
# Number of searches: 17435
# ----------------------------
# Iteration 43:
# Cells per terrain: [499, 752, 746, 503]
# Visits per terrain: [499 617   0   0]
# Number of searches: 1116
# ----------------------------
# Iteration 44:
# Cells per terrain: [475, 733, 747, 545]
# Visits per terrain: [ 950 2087 3735 2725]
# Number of searches: 9497
# ----------------------------
# Iteration 45:
# Cells per terrain: [520, 777, 701, 502]
# Visits per terrain: [520 152   0   0]
# Number of searches: 672
# ----------------------------
# Iteration 46:
# Cells per terrain: [472, 768, 768, 492]
# Visits per terrain: [472  87   0   0]
# Number of searches: 559
# ----------------------------
# Iteration 47:
# Cells per terrain: [465, 718, 779, 538]
# Visits per terrain: [465 385   0   0]
# Number of searches: 850
# ----------------------------
# Iteration 48:
# Cells per terrain: [481, 766, 760, 493]
# Visits per terrain: [ 481 1336 1520    0]
# Number of searches: 3337
# ----------------------------
# Iteration 49:
# Cells per terrain: [502, 764, 728, 506]
# Visits per terrain: [502 320   0   0]
# Number of searches: 822
# Average visits per terrain: [567.4288 739.252  831.6032 701.8036]
# ----------------------------
# Terrain 2
# ----------------------------
# Iteration 0:
# Cells per terrain: [485, 739, 768, 508]
# Visits per terrain: [ 970 2217 4425 3556]
# Number of searches: 11168
# ----------------------------
# Iteration 1:
# Cells per terrain: [497, 741, 722, 540]
# Visits per terrain: [ 497 1482 2734    0]
# Number of searches: 4713
# ----------------------------
# Iteration 2:
# Cells per terrain: [500, 785, 712, 503]
# Visits per terrain: [1000 1570 3402 2012]
# Number of searches: 7984
# ----------------------------
# Iteration 3:
# Cells per terrain: [532, 744, 735, 489]
# Visits per terrain: [532 744 161   0]
# Number of searches: 1437
# ----------------------------
# Iteration 4:
# Cells per terrain: [514, 760, 710, 516]
# Visits per terrain: [ 514 1520 1709    0]
# Number of searches: 3743
# ----------------------------
# Iteration 5:
# Cells per terrain: [515, 731, 751, 503]
# Visits per terrain: [1030 2193 5623 7042]
# Number of searches: 15888
# ----------------------------
# Iteration 6:
# Cells per terrain: [527, 733, 743, 497]
# Visits per terrain: [527 733  19   0]
# Number of searches: 1279
# ----------------------------
# Iteration 7:
# Cells per terrain: [520, 741, 741, 498]
# Visits per terrain: [ 520  741 1006    0]
# Number of searches: 2267
# ----------------------------
# Iteration 8:
# Cells per terrain: [497, 790, 712, 501]
# Visits per terrain: [497 790 408   0]
# Number of searches: 1695
# ----------------------------
# Iteration 9:
# Cells per terrain: [494, 763, 759, 484]
# Visits per terrain: [ 494  843 1392    0]
# Number of searches: 2729
# ----------------------------
# Iteration 10:
# Cells per terrain: [520, 740, 733, 507]
# Visits per terrain: [ 520 1480 1991    0]
# Number of searches: 3991
# ----------------------------
# Iteration 11:
# Cells per terrain: [492, 745, 772, 491]
# Visits per terrain: [ 984 1490 3500 1964]
# Number of searches: 7938
# ----------------------------
# Iteration 12:
# Cells per terrain: [510, 741, 749, 500]
# Visits per terrain: [510 741 417   0]
# Number of searches: 1668
# ----------------------------
# Iteration 13:
# Cells per terrain: [484, 749, 733, 534]
# Visits per terrain: [ 484 1498 2591    0]
# Number of searches: 4573
# ----------------------------
# Iteration 14:
# Cells per terrain: [508, 766, 758, 468]
# Visits per terrain: [508 766 455   0]
# Number of searches: 1729
# ----------------------------
# Iteration 15:
# Cells per terrain: [485, 780, 723, 512]
# Visits per terrain: [ 485 1560 1603    0]
# Number of searches: 3648
# ----------------------------
# Iteration 16:
# Cells per terrain: [511, 728, 746, 515]
# Visits per terrain: [511 728 570   0]
# Number of searches: 1809
# ----------------------------
# Iteration 17:
# Cells per terrain: [512, 762, 715, 511]
# Visits per terrain: [ 512  812 1253    0]
# Number of searches: 2577
# ----------------------------
# Iteration 18:
# Cells per terrain: [496, 798, 704, 502]
# Visits per terrain: [ 496 1596 2774    0]
# Number of searches: 4866
# ----------------------------
# Iteration 19:
# Cells per terrain: [524, 735, 759, 482]
# Visits per terrain: [1048 1470 3391 1928]
# Number of searches: 7837
# ----------------------------
# Iteration 20:
# Cells per terrain: [527, 749, 733, 491]
# Visits per terrain: [527 749 203   0]
# Number of searches: 1479
# ----------------------------
# Iteration 21:
# Cells per terrain: [502, 743, 752, 503]
# Visits per terrain: [ 502 1486 2617    0]
# Number of searches: 4605
# ----------------------------
# Iteration 22:
# Cells per terrain: [507, 754, 747, 492]
# Visits per terrain: [ 507  982 1382    0]
# Number of searches: 2871
# ----------------------------
# Iteration 23:
# Cells per terrain: [524, 737, 768, 471]
# Visits per terrain: [ 524 1474 2868    0]
# Number of searches: 4866
# ----------------------------
# Iteration 24:
# Cells per terrain: [516, 729, 746, 509]
# Visits per terrain: [ 1548  2916  7723 12216]
# Number of searches: 24403
# ----------------------------
# Iteration 25:
# Cells per terrain: [495, 772, 715, 518]
# Visits per terrain: [ 495  772 1221    0]
# Number of searches: 2488
# ----------------------------
# Iteration 26:
# Cells per terrain: [503, 728, 761, 508]
# Visits per terrain: [ 1509  2912  7706 12192]
# Number of searches: 24319
# ----------------------------
# Iteration 27:
# Cells per terrain: [490, 776, 751, 483]
# Visits per terrain: [ 980 2328 5828 6762]
# Number of searches: 15898
# ----------------------------
# Iteration 28:
# Cells per terrain: [475, 746, 768, 511]
# Visits per terrain: [475 746 184   0]
# Number of searches: 1405
# ----------------------------
# Iteration 29:
# Cells per terrain: [497, 735, 756, 512]
# Visits per terrain: [ 497 1470 1754    0]
# Number of searches: 3721
# ----------------------------
# Iteration 30:
# Cells per terrain: [465, 742, 779, 514]
# Visits per terrain: [ 930 2226 5202 5140]
# Number of searches: 13498
# ----------------------------
# Iteration 31:
# Cells per terrain: [498, 781, 732, 489]
# Visits per terrain: [ 498 1562 1967    0]
# Number of searches: 4027
# ----------------------------
# Iteration 32:
# Cells per terrain: [453, 741, 772, 534]
# Visits per terrain: [ 453 1482 2147    0]
# Number of searches: 4082
# ----------------------------
# Iteration 33:
# Cells per terrain: [513, 746, 741, 500]
# Visits per terrain: [513 746 197   0]
# Number of searches: 1456
# ----------------------------
# Iteration 34:
# Cells per terrain: [531, 756, 752, 461]
# Visits per terrain: [ 531 1512 2628    0]
# Number of searches: 4671
# ----------------------------
# Iteration 35:
# Cells per terrain: [513, 727, 741, 519]
# Visits per terrain: [ 513 1454 2958    0]
# Number of searches: 4925
# ----------------------------
# Iteration 36:
# Cells per terrain: [496, 761, 761, 482]
# Visits per terrain: [ 992 1522 3131 1928]
# Number of searches: 7573
# ----------------------------
# Iteration 37:
# Cells per terrain: [541, 722, 732, 505]
# Visits per terrain: [541 722 394   0]
# Number of searches: 1657
# ----------------------------
# Iteration 38:
# Cells per terrain: [500, 723, 780, 497]
# Visits per terrain: [1000 1446 3895 1988]
# Number of searches: 8329
# ----------------------------
# Iteration 39:
# Cells per terrain: [506, 745, 770, 479]
# Visits per terrain: [ 506 1490 3044    0]
# Number of searches: 5040
# ----------------------------
# Iteration 40:
# Cells per terrain: [499, 720, 772, 509]
# Visits per terrain: [ 499 1011 1542    0]
# Number of searches: 3052
# ----------------------------
# Iteration 41:
# Cells per terrain: [496, 770, 753, 481]
# Visits per terrain: [496 770 515   0]
# Number of searches: 1781
# ----------------------------
# Iteration 42:
# Cells per terrain: [493, 743, 732, 532]
# Visits per terrain: [ 986 2229 5725 7448]
# Number of searches: 16388
# ----------------------------
# Iteration 43:
# Cells per terrain: [514, 697, 779, 510]
# Visits per terrain: [1028 2091 4538 3570]
# Number of searches: 11227
# ----------------------------
# Iteration 44:
# Cells per terrain: [491, 764, 738, 507]
# Visits per terrain: [ 982 2292 5043 5070]
# Number of searches: 13387
# ----------------------------
# Iteration 45:
# Cells per terrain: [511, 773, 730, 486]
# Visits per terrain: [511 773 378   0]
# Number of searches: 1662
# ----------------------------
# Iteration 46:
# Cells per terrain: [480, 713, 782, 525]
# Visits per terrain: [ 480 1426 1842    0]
# Number of searches: 3748
# ----------------------------
# Iteration 47:
# Cells per terrain: [553, 716, 712, 519]
# Visits per terrain: [553 950 940   0]
# Number of searches: 2443
# ----------------------------
# Iteration 48:
# Cells per terrain: [498, 759, 729, 514]
# Visits per terrain: [  996  3036  7048 10794]
# Number of searches: 21874
# ----------------------------
# Iteration 49:
# Cells per terrain: [523, 768, 709, 500]
# Visits per terrain: [ 523 1536 2607    0]
# Number of searches: 4666
# Average visits per terrain: [ 686.028576 1436.48504  2549.652064 1686.236072]
# ----------------------------
# Terrain 3
# ----------------------------
# Iteration 0:
# Cells per terrain: [486, 760, 723, 531]
# Visits per terrain: [ 972 2280 4338 4980]
# Number of searches: 12570
# ----------------------------
# Iteration 1:
# Cells per terrain: [483, 768, 755, 494]
# Visits per terrain: [ 483 1536 3020   93]
# Number of searches: 5132
# ----------------------------
# Iteration 2:
# Cells per terrain: [488, 738, 753, 521]
# Visits per terrain: [  976  2952  7530 11313]
# Number of searches: 22771
# ----------------------------
# Iteration 3:
# Cells per terrain: [505, 779, 732, 484]
# Visits per terrain: [ 518 1558 2928  553]
# Number of searches: 5557
# ----------------------------
# Iteration 4:
# Cells per terrain: [519, 752, 770, 459]
# Visits per terrain: [1038 2256 3850 2546]
# Number of searches: 9690
# ----------------------------
# Iteration 5:
# Cells per terrain: [490, 751, 751, 508]
# Visits per terrain: [ 1470  3004  8261 12242]
# Number of searches: 24977
# ----------------------------
# Iteration 6:
# Cells per terrain: [507, 750, 762, 481]
# Visits per terrain: [1014 1500 3810 2292]
# Number of searches: 8616
# ----------------------------
# Iteration 7:
# Cells per terrain: [507, 748, 737, 508]
# Visits per terrain: [1014 1496 2948 1178]
# Number of searches: 6636
# ----------------------------
# Iteration 8:
# Cells per terrain: [476, 741, 763, 520]
# Visits per terrain: [ 952 1482 3052 1258]
# Number of searches: 6744
# ----------------------------
# Iteration 9:
# Cells per terrain: [509, 766, 713, 512]
# Visits per terrain: [1018 2298 4278 4637]
# Number of searches: 12231
# ----------------------------
# Iteration 10:
# Cells per terrain: [508, 742, 730, 520]
# Visits per terrain: [1016 2226 4380 5129]
# Number of searches: 12751
# ----------------------------
# Iteration 11:
# Cells per terrain: [499, 775, 721, 505]
# Visits per terrain: [ 499 1550 2884    8]
# Number of searches: 4941
# ----------------------------
# Iteration 12:
# Cells per terrain: [507, 723, 743, 527]
# Visits per terrain: [1014 1446 2972 1583]
# Number of searches: 7015
# ----------------------------
# Iteration 13:
# Cells per terrain: [481, 736, 764, 519]
# Visits per terrain: [ 481 1472 3056  312]
# Number of searches: 5321
# ----------------------------
# Iteration 14:
# Cells per terrain: [493, 742, 769, 496]
# Visits per terrain: [ 986 2226 4614 3904]
# Number of searches: 11730
# ----------------------------
# Iteration 15:
# Cells per terrain: [506, 724, 744, 526]
# Visits per terrain: [1012 1448 2976  876]
# Number of searches: 6312
# ----------------------------
# Iteration 16:
# Cells per terrain: [506, 766, 726, 502]
# Visits per terrain: [1012 3064 6534 9521]
# Number of searches: 20131
# ----------------------------
# Iteration 17:
# Cells per terrain: [517, 764, 719, 500]
# Visits per terrain: [ 517 1528 2876  247]
# Number of searches: 5168
# ----------------------------
# Iteration 18:
# Cells per terrain: [507, 747, 744, 502]
# Visits per terrain: [1014 2241 3720 2819]
# Number of searches: 9794
# ----------------------------
# Iteration 19:
# Cells per terrain: [487, 758, 767, 488]
# Visits per terrain: [ 569 1516 3068  506]
# Number of searches: 5659
# ----------------------------
# Iteration 20:
# Cells per terrain: [475, 761, 743, 521]
# Visits per terrain: [ 950 2283 5201 6302]
# Number of searches: 14736
# ----------------------------
# Iteration 21:
# Cells per terrain: [474, 760, 785, 481]
# Visits per terrain: [ 948 2280 5495 5240]
# Number of searches: 13963
# ----------------------------
# Iteration 22:
# Cells per terrain: [492, 779, 748, 481]
# Visits per terrain: [ 492 1558 2992   51]
# Number of searches: 5093
# ----------------------------
# Iteration 23:
# Cells per terrain: [493, 732, 768, 507]
# Visits per terrain: [ 549 1464 3072  718]
# Number of searches: 5803
# ----------------------------
# Iteration 24:
# Cells per terrain: [537, 713, 755, 495]
# Visits per terrain: [1074 1426 3775 2413]
# Number of searches: 8688
# ----------------------------
# Iteration 25:
# Cells per terrain: [511, 785, 740, 464]
# Visits per terrain: [1022 1570 3700 2040]
# Number of searches: 8332
# ----------------------------
# Iteration 26:
# Cells per terrain: [511, 776, 772, 441]
# Visits per terrain: [1022 2328 5404 4604]
# Number of searches: 13358
# ----------------------------
# Iteration 27:
# Cells per terrain: [474, 754, 743, 529]
# Visits per terrain: [ 948 2262 3715 2839]
# Number of searches: 9764
# ----------------------------
# Iteration 28:
# Cells per terrain: [491, 724, 767, 518]
# Visits per terrain: [ 982 2172 3835 2825]
# Number of searches: 9814
# ----------------------------
# Iteration 29:
# Cells per terrain: [491, 782, 733, 494]
# Visits per terrain: [ 982 1564 2932 1174]
# Number of searches: 6652
# ----------------------------
# Iteration 30:
# Cells per terrain: [488, 737, 789, 486]
# Visits per terrain: [ 976 2211 4734 4109]
# Number of searches: 12030
# ----------------------------
# Iteration 31:
# Cells per terrain: [498, 788, 742, 472]
# Visits per terrain: [ 996 3152 6678 8991]
# Number of searches: 19817
# ----------------------------
# Iteration 32:
# Cells per terrain: [472, 766, 772, 490]
# Visits per terrain: [ 944 2298 4632 4829]
# Number of searches: 12703
# ----------------------------
# Iteration 33:
# Cells per terrain: [489, 781, 744, 486]
# Visits per terrain: [  978  3124  7440 10606]
# Number of searches: 22148
# ----------------------------
# Iteration 34:
# Cells per terrain: [559, 739, 733, 469]
# Visits per terrain: [ 1118  2956  7330 10610]
# Number of searches: 22014
# ----------------------------
# Iteration 35:
# Cells per terrain: [504, 721, 768, 507]
# Visits per terrain: [ 628 1442 3072  627]
# Number of searches: 5769
# ----------------------------
# Iteration 36:
# Cells per terrain: [508, 771, 734, 487]
# Visits per terrain: [1016 2313 4404 4348]
# Number of searches: 12081
# ----------------------------
# Iteration 37:
# Cells per terrain: [502, 733, 767, 498]
# Visits per terrain: [1004 1466 3068 1406]
# Number of searches: 6944
# ----------------------------
# Iteration 38:
# Cells per terrain: [500, 764, 721, 515]
# Visits per terrain: [1000 2292 4326 3759]
# Number of searches: 11377
# ----------------------------
# Iteration 39:
# Cells per terrain: [483, 747, 749, 521]
# Visits per terrain: [ 966 1494 2996 1885]
# Number of searches: 7341
# ----------------------------
# Iteration 40:
# Cells per terrain: [490, 762, 724, 524]
# Visits per terrain: [ 980 1524 2896 1262]
# Number of searches: 6662
# ----------------------------
# Iteration 41:
# Cells per terrain: [475, 756, 745, 524]
# Visits per terrain: [ 950 2268 4470 4152]
# Number of searches: 11840
# ----------------------------
# Iteration 42:
# Cells per terrain: [515, 735, 761, 489]
# Visits per terrain: [1030 2205 4566 3661]
# Number of searches: 11462
# ----------------------------
# Iteration 43:
# Cells per terrain: [519, 769, 733, 479]
# Visits per terrain: [1038 2307 5864 6807]
# Number of searches: 16016
# ----------------------------
# Iteration 44:
# Cells per terrain: [498, 787, 715, 500]
# Visits per terrain: [ 996 2361 5005 5259]
# Number of searches: 13621
# ----------------------------
# Iteration 45:
# Cells per terrain: [461, 760, 773, 506]
# Visits per terrain: [ 922 1520 3092 1391]
# Number of searches: 6925
# ----------------------------
# Iteration 46:
# Cells per terrain: [519, 778, 702, 501]
# Visits per terrain: [1038 1556 3510 2270]
# Number of searches: 8374
# ----------------------------
# Iteration 47:
# Cells per terrain: [526, 739, 739, 496]
# Visits per terrain: [ 1578  3695 10346 16881]
# Number of searches: 32500
# ----------------------------
# Iteration 48:
# Cells per terrain: [464, 769, 738, 529]
# Visits per terrain: [ 928 1538 3690 2222]
# Number of searches: 8378
# ----------------------------
# Iteration 49:
# Cells per terrain: [506, 755, 739, 500]
# Visits per terrain: [1012 1510 2956 1014]
# Number of searches: 6492
# Average visits per terrain: [ 946.56057152 2053.0897008  4376.81304128 3839.56472144]
# Average Matrix:
# array([[ 314,  239,  510,  326],
#        [ 567,  739,  831,  701],
#        [ 686, 1436, 2549, 1686],
#        [ 946, 2053, 4376, 3839]])
# Rule 2 performance: [ 69519 140614 315080 554443]
# ----------------------------
# Terrain 0
# ----------------------------
# Iteration 0:
# Cells per terrain: [512, 716, 746, 526]
# Visits per terrain: [472 660 688 479]
# Number of searches: 2299
# ----------------------------
# Iteration 1:
# Cells per terrain: [489, 729, 803, 479]
# Visits per terrain: [381 555 608 356]
# Number of searches: 1900
# ----------------------------
# Iteration 2:
# Cells per terrain: [505, 786, 739, 470]
# Visits per terrain: [121 193 174  93]
# Number of searches: 581
# ----------------------------
# Iteration 3:
# Cells per terrain: [509, 711, 776, 504]
# Visits per terrain: [212 298 325 195]
# Number of searches: 1030
# ----------------------------
# Iteration 4:
# Cells per terrain: [495, 756, 718, 531]
# Visits per terrain: [ 81 105 109  79]
# Number of searches: 374
# ----------------------------
# Iteration 5:
# Cells per terrain: [500, 720, 777, 503]
# Visits per terrain: [469 671 713 464]
# Number of searches: 2317
# ----------------------------
# Iteration 6:
# Cells per terrain: [521, 742, 780, 457]
# Visits per terrain: [348 545 553 334]
# Number of searches: 1780
# ----------------------------
# Iteration 7:
# Cells per terrain: [475, 764, 738, 523]
# Visits per terrain: [  698  1528  5166 11506]
# Number of searches: 18898
# ----------------------------
# Iteration 8:
# Cells per terrain: [476, 743, 769, 512]
# Visits per terrain: [  555  1486  5383 11264]
# Number of searches: 18688
# ----------------------------
# Iteration 9:
# Cells per terrain: [481, 731, 728, 560]
# Visits per terrain: [415 621 644 482]
# Number of searches: 2162
# ----------------------------
# Iteration 10:
# Cells per terrain: [468, 756, 792, 484]
# Visits per terrain: [201 320 305 201]
# Number of searches: 1027
# ----------------------------
# Iteration 11:
# Cells per terrain: [531, 726, 746, 497]
# Visits per terrain: [503 700 703 466]
# Number of searches: 2372
# ----------------------------
# Iteration 12:
# Cells per terrain: [529, 730, 734, 507]
# Visits per terrain: [49 76 65 40]
# Number of searches: 230
# ----------------------------
# Iteration 13:
# Cells per terrain: [503, 751, 747, 499]
# Visits per terrain: [17 30 39 16]
# Number of searches: 102
# ----------------------------
# Iteration 14:
# Cells per terrain: [448, 790, 744, 518]
# Visits per terrain: [395 703 668 450]
# Number of searches: 2216
# ----------------------------
# Iteration 15:
# Cells per terrain: [506, 759, 732, 503]
# Visits per terrain: [252 402 389 241]
# Number of searches: 1284
# ----------------------------
# Iteration 16:
# Cells per terrain: [494, 678, 822, 506]
# Visits per terrain: [392 576 686 422]
# Number of searches: 2076
# ----------------------------
# Iteration 17:
# Cells per terrain: [488, 749, 748, 515]
# Visits per terrain: [354 529 531 378]
# Number of searches: 1792
# ----------------------------
# Iteration 18:
# Cells per terrain: [490, 742, 743, 525]
# Visits per terrain: [213 336 326 245]
# Number of searches: 1120
# ----------------------------
# Iteration 19:
# Cells per terrain: [488, 756, 730, 526]
# Visits per terrain: [348 530 506 383]
# Number of searches: 1767
# Average visits per terrain: [ 323.8   543.2   929.05 1404.7 ]
# ----------------------------
# Terrain 1
# ----------------------------
# Iteration 0:
# Cells per terrain: [507, 787, 760, 446]
# Visits per terrain: [281 410 406 247]
# Number of searches: 1344
# ----------------------------
# Iteration 1:
# Cells per terrain: [521, 731, 745, 503]
# Visits per terrain: [ 521 1243 2980 6036]
# Number of searches: 10780
# ----------------------------
# Iteration 2:
# Cells per terrain: [473, 742, 802, 483]
# Visits per terrain: [327 515 534 348]
# Number of searches: 1724
# ----------------------------
# Iteration 3:
# Cells per terrain: [475, 743, 768, 514]
# Visits per terrain: [31 59 66 32]
# Number of searches: 188
# ----------------------------
# Iteration 4:
# Cells per terrain: [456, 756, 810, 478]
# Visits per terrain: [340 582 629 355]
# Number of searches: 1906
# ----------------------------
# Iteration 5:
# Cells per terrain: [500, 767, 739, 494]
# Visits per terrain: [139 183 214 138]
# Number of searches: 674
# ----------------------------
# Iteration 6:
# Cells per terrain: [511, 729, 765, 495]
# Visits per terrain: [ 84 106 114  70]
# Number of searches: 374
# ----------------------------
# Iteration 7:
# Cells per terrain: [522, 749, 708, 521]
# Visits per terrain: [128 181 165 133]
# Number of searches: 607
# ----------------------------
# Iteration 8:
# Cells per terrain: [537, 739, 735, 489]
# Visits per terrain: [103 156 162 121]
# Number of searches: 542
# ----------------------------
# Iteration 9:
# Cells per terrain: [501, 762, 738, 499]
# Visits per terrain: [290 431 409 291]
# Number of searches: 1421
# ----------------------------
# Iteration 10:
# Cells per terrain: [521, 774, 752, 453]
# Visits per terrain: [245 389 387 248]
# Number of searches: 1269
# ----------------------------
# Iteration 11:
# Cells per terrain: [513, 762, 755, 470]
# Visits per terrain: [460 686 663 405]
# Number of searches: 2214
# ----------------------------
# Iteration 12:
# Cells per terrain: [509, 737, 771, 483]
# Visits per terrain: [ 509  845 3084 5796]
# Number of searches: 10234
# ----------------------------
# Iteration 13:
# Cells per terrain: [485, 817, 712, 486]
# Visits per terrain: [ 79 108  85  59]
# Number of searches: 331
# ----------------------------
# Iteration 14:
# Cells per terrain: [529, 754, 721, 496]
# Visits per terrain: [ 1587  3386 10094 22816]
# Number of searches: 37883
# ----------------------------
# Iteration 15:
# Cells per terrain: [536, 741, 704, 519]
# Visits per terrain: [219 285 264 184]
# Number of searches: 952
# ----------------------------
# Iteration 16:
# Cells per terrain: [516, 743, 763, 478]
# Visits per terrain: [252 356 374 242]
# Number of searches: 1224
# ----------------------------
# Iteration 17:
# Cells per terrain: [496, 774, 738, 492]
# Visits per terrain: [292 472 448 325]
# Number of searches: 1537
# ----------------------------
# Iteration 18:
# Cells per terrain: [498, 736, 742, 524]
# Visits per terrain: [356 514 526 376]
# Number of searches: 1772
# ----------------------------
# Iteration 19:
# Cells per terrain: [503, 720, 762, 515]
# Visits per terrain: [48 68 80 49]
# Number of searches: 245
# Average visits per terrain: [ 330.74    575.91   1130.6525 1983.785 ]
# ----------------------------
# Terrain 2
# ----------------------------
# Iteration 0:
# Cells per terrain: [517, 752, 713, 518]
# Visits per terrain: [ 517 1504 3416 7252]
# Number of searches: 12689
# ----------------------------
# Iteration 1:
# Cells per terrain: [487, 753, 778, 482]
# Visits per terrain: [ 487 1506 3787 6748]
# Number of searches: 12528
# ----------------------------
# Iteration 2:

# %%
def terrain_analysis(num_trials, a):

  terrain_list = ["Flat", "Hilly", "Forested", "Caves"]
  factor_list = ["Rule_1", "Rule_2"]
  comparision_table = pd.DataFrame(index = terrain_list, columns = factor_list)

  false_negative_rate = [0.1, 0.3, 0.7, 0.9]

  ## Flat terrain
  total_flat_1 = 0
  total_flat_2 = 0

  for i in range(num_trials):
    environment = assign_terrain(a, 0)
    terrain_location = environment[1]
    initial_belief = 1/(a * a)
    
    belief_map = np.full((a, a), initial_belief)
    total_flat_1 += rule_1_approach(environment, belief_map, false_negative_rate)
    belief_map = np.full((a, a), initial_belief)
    total_flat_2 += rule_2_approach(environment, belief_map, false_negative_rate)

  comparision_table.loc['Flat']['Rule_1'] = total_flat_1/num_trials
  comparision_table.loc['Flat']['Rule_2'] = total_flat_2/num_trials

  ## Hilly terrain
  total_hilly_1 = 0
  total_hilly_2 = 0

  for i in range(num_trials):
    environment = assign_terrain(a, 1)
    terrain_location = environment[1]
    initial_belief = 1/(a * a)
    
    belief_map = np.full((a, a), initial_belief)
    total_hilly_1 += rule_1_approach(environment, belief_map, false_negative_rate)
    belief_map = np.full((a, a), initial_belief)
    total_hilly_2 += rule_2_approach(environment, belief_map, false_negative_rate)

  comparision_table.loc['Hilly']['Rule_1'] = total_hilly_1/num_trials
  comparision_table.loc['Hilly']['Rule_2'] = total_hilly_2/num_trials

  ## Forested terrain
  total_forested_1 = 0
  total_forested_2 = 0

  for i in range(num_trials):
    environment = assign_terrain(a, 1)
    terrain_location = environment[1]
    initial_belief = 1/(a * a)
    
    belief_map = np.full((a, a), initial_belief)
    total_forested_1 += rule_1_approach(environment, belief_map, false_negative_rate)
    belief_map = np.full((a, a), initial_belief)
    total_forested_2 += rule_2_approach(environment, belief_map, false_negative_rate)

  comparision_table.loc['Forested']['Rule_1'] = total_forested_1/num_trials
  comparision_table.loc['Forested']['Rule_2'] = total_forested_2/num_trials

  ## Caves terrain
  total_caves_1 = 0
  total_caves_2 = 0

  for i in range(num_trials):
    environment = assign_terrain(a, 1)
    terrain_location = environment[1]
    initial_belief = 1/(a * a)
    
    belief_map = np.full((a, a), initial_belief)
    total_caves_1 += rule_1_approach(environment, belief_map, false_negative_rate)
    belief_map = np.full((a, a), initial_belief)
    total_caves_2 += rule_2_approach(environment, belief_map, false_negative_rate)

  comparision_table.loc['Caves']['Rule_1'] = total_caves_1/num_trials
  comparision_table.loc['Caves']['Rule_2'] = total_caves_2/num_trials
  
  print(comparision_table)
  # ax = comparision_table.plot.bar(rot=0)

# %%
terrain_analysis(50, 50)
# Out:
#            Rule_1   Rule_2
# Flat       3007.7   919.56
# Hilly     6213.18  1783.44
# Forested  4255.46  1918.96
# Caves      4487.9   2252.5
